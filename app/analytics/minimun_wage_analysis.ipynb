# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv(
    "../../data/processed/brazil-teams-jersey-price-processed.csv",
    usecols=[
        "team",
        "state",
        "year",
        "value",
        "value_int",
        "wage_value",
        "wage_value_percent",
        "wage_value_percent_int",
    ],
)

df.head()
# Out:
#        team state  year   value  value_int  wage_value  wage_value_percent  \
# 0  Flamengo    RJ  2012  200.00        200       622.0               32.15
# 1  Flamengo    RJ  2013  199.90        199       678.0               29.35
# 2  Flamengo    RJ  2014  219.90        219       724.0               30.25
# 3  Flamengo    RJ  2015  219.00        219       788.0               27.79
# 4  Flamengo    RJ  2016  249.99        249       880.0               28.30
#
#    wage_value_percent_int
# 0                      32
# 1                      29
# 2                      30
# 3                      27
# 4                      28

# %%
df_teams = df.query("team in ('Flamengo', 'Vasco', 'Corinthians', 'Palmeiras')")
df_teams.head()
# Out:
#        team state  year   value  value_int  wage_value  wage_value_percent  \
# 0  Flamengo    RJ  2012  200.00        200       622.0               32.15
# 1  Flamengo    RJ  2013  199.90        199       678.0               29.35
# 2  Flamengo    RJ  2014  219.90        219       724.0               30.25
# 3  Flamengo    RJ  2015  219.00        219       788.0               27.79
# 4  Flamengo    RJ  2016  249.99        249       880.0               28.30
#
#    wage_value_percent_int
# 0                      32
# 1                      29
# 2                      30
# 3                      27
# 4                      28
