# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv(
    "../../data/processed/brazil-teams-jersey-price-processed.csv",
    usecols=[
        "team",
        "state",
        "year",
        "value",
        "value_int",
        "value_add_05",
        "value_add_10",
        "value_add_15",
        "value_sub_05",
        "value_sub_10",
        "value_sub_15",
    ],
)

df.head()
# Out:
#        team state  year   value  value_int  value_add_05  value_add_10  \
# 0  Flamengo    RJ  2012  200.00        200           210           220
# 1  Flamengo    RJ  2013  199.90        199           208           218
# 2  Flamengo    RJ  2014  219.90        219           229           240
# 3  Flamengo    RJ  2015  219.00        219           229           240
# 4  Flamengo    RJ  2016  249.99        249           261           273
#
#    value_add_15  value_sub_05  value_sub_10  value_sub_15
# 0           229           190           180           170
# 1           228           189           179           169
# 2           251           208           197           186
# 3           251           208           197           186
# 4           286           236           224           211

# %%
flamengo_df = df.query("team == 'Flamengo'")

plt.figure(figsize=(16, 6))

g = sns.relplot(
    data=flamengo_df, kind="line", x="year", y="value_int", hue="team", marker="o"
)
plt.xticks(
    flamengo_df["year"], rotation=45
)  # Explicitly set the ticks to every year in the dataframe

plt.title("Evolução do preço da camisa oficial do Flamengo (2012/24)", fontsize=15)
plt.xlabel("Anos", fontsize=14)
plt.ylabel("Valores (R$)", fontsize=14)

sns.move_legend(g, "upper left", bbox_to_anchor=(0.90, 0.45), title="Time")

plt.tight_layout()
plt.show()

# %%
vasco_df = df.query("team == 'Vasco'")

plt.figure(figsize=(16, 6))

g = sns.relplot(
    data=vasco_df, kind="line", x="year", y="value_int", hue="team", marker="o"
)
plt.xticks(
    vasco_df["year"], rotation=45
)  # Explicitly set the ticks to every year in the dataframe

plt.title("Evolução do preço da camisa oficial do Vasco (2012/24)", fontsize=15)
plt.xlabel("Anos", fontsize=14)
plt.ylabel("Valores (R$)", fontsize=14)

sns.move_legend(g, "upper left", bbox_to_anchor=(0.90, 0.45), title="Time")

plt.tight_layout()
plt.show()

# %%
corinthians_df = df.query("team == 'Corinthians'")

plt.figure(figsize=(16, 6))

g = sns.relplot(
    data=corinthians_df, kind="line", x="year", y="value_int", hue="team", marker="o"
)
plt.xticks(
    corinthians_df["year"], rotation=45
)  # Explicitly set the ticks to every year in the dataframe

plt.title("Evolução do preço da camisa oficial do Corinthians (2012/24)", fontsize=15)
plt.xlabel("Anos", fontsize=14)
plt.ylabel("Valores (R$)", fontsize=14)

sns.move_legend(g, "upper left", bbox_to_anchor=(0.90, 0.45), title="Time")

plt.tight_layout()
plt.show()

# %%
palmeiras_df = df.query("team == 'Palmeiras'")

plt.figure(figsize=(16, 6))

g = sns.relplot(
    data=palmeiras_df, kind="line", x="year", y="value_int", hue="team", marker="o"
)
plt.xticks(
    palmeiras_df["year"], rotation=45
)  # Explicitly set the ticks to every year in the dataframe

plt.title("Evolução do preço da camisa oficial do Palmeiras (2012/24)", fontsize=15)
plt.xlabel("Anos", fontsize=14)
plt.ylabel("Valores (R$)", fontsize=14)

sns.move_legend(g, "upper left", bbox_to_anchor=(0.90, 0.45), title="Time")

plt.tight_layout()
plt.show()

# %%
df_teams = df.query("team in ('Flamengo', 'Vasco', 'Corinthians', 'Palmeiras')")

plt.figure(figsize=(16, 6))

g = sns.relplot(
    data=df_teams, kind="line", x="year", hue="team", y="value_int", marker="o"
)
plt.xticks(
    df_teams["year"].unique(), rotation=45
)  # Explicitly set the ticks to every year in the dataframe

plt.title("Comparativo de preços das camisas dos clubes (2012/24)", fontsize=15)
plt.xlabel("Anos", fontsize=14)
plt.ylabel("Valores (R$)", fontsize=14)

sns.move_legend(g, "upper left", bbox_to_anchor=(0.80, 0.45), title="Times")

plt.tight_layout()
plt.show()
